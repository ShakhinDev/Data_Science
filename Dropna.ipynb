# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data_nan.csv", index_col=0)
df.head() #Yangi DF yaratamiz. Jadval tarkibidagi `NaN` qiymatlarg ahamiyat bering.
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %% [markdown]
# **Mavjud bo'lmagan qiymatlarga ishlov berishning yagona, universal formulasi yo'q.**
#
# Bunday holatda sizning birinchi savolingiz "Nima uchun mu qiymat mavjud emas? Ma'lumot yozib olinmaganmi yoki umuman mavjud emasmi?" bo'lishi kerak. Misol uchun, siz so'rovnoma yordamida odamlar haqida ma'lumotlar jamlayapsiz, so'rovnomangizda "nikohdan o'tgan yilingiz" degan bo'lim bor. Tabiiyki, turmush qurmaghanlar uchun bu qiymat mabjud bo'lmaydi va bu xato emas. Aksincha, "tug'ilgan yilingiz" qiymati mavjud bo'lmasligi esa, ma'lumot mavjud lekin yozib olinmaganini anglatadi.
#
# Data Science muhandisi sifatida siz mavjud bo'lmagan ma'lumotlarni topishga, buning imkoni bo'lmasa ularni approksimasiya qilishga (tahminiy qiymat topishga) harakat qilishingiz, buni ham iloji bo'lmasa bunday ustun (yoki qatorlardan) voz kechishni hal qilishingiz kerak bo'ladi.
#
# Avvalo, keling, DF da mavjud bo'lmagan (`NaN`) qiymatlar sonini topaylik.

# %% [markdown]
# # `.isnul()`
# `.isnull()` metodi yordamida ustun qiymati `NaN` ga teng (`True`) yoki yo'q (`False`) ekanini tekshiramiz. Ya'ni, `NaN` qiymat o'rnida `True` ko'ramiz.

# %%
df.isnull()
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 0        False       False       False   False        False             False
# 1        False       False        True   False        False             False
# 2        False       False       False   False        False             False
# 3        False       False       False   False        False             False
# 4        False       False       False   False        False             False
# ...        ...         ...         ...     ...          ...               ...
# 81       False       False       False   False        False             False
# 82       False       False        True   False         True             False
# 86       False       False       False    True        False             False
# 87       False       False       False   False         True             False
# 88       False       False       False   False        False             False
#
# ...

# %% [markdown]
# # Boolean qiymatlar `True=1`, `False=0` bo'lgani uchun `.sum()` metodi yordamida har ustundagi jami `NaN` qiymatlar sonini ko'rishimiz mumkin.

# %%
df.isnull().sum()
# Out:
# company              0
# body-style           0
# wheel-base          15
# length              13
# engine-type         12
# num-of-cylinders     0
# horsepower          16
# average-mileage     15
# price                3
# dtype: int64

# %% [markdown]
# **Ko'rib turganingizdek, `horsepower` ustunida 16 ta, `wheel-base` va `average-milega` ustunlarida 15 tadan va hokazo qiymatlar mavjud emas.
#
# Keling bu ko'rsatkichlarni jami ma'lumotlarning foizi sifatida chiqaramiz.**

# %%
nulls=df.isnull().sum()
rows = len(df)
(nulls/rows)*100
# Out:
# company              0.000000
# body-style           0.000000
# wheel-base          24.590164
# length              21.311475
# engine-type         19.672131
# num-of-cylinders     0.000000
# horsepower          26.229508
# average-mileage     24.590164
# price                4.918033
# dtype: float64

# %%
df.dropna()
# Out:
#           company   body-style  wheel-base  length engine-type  \
# index
# 3            audi        sedan        99.8   176.6         ohc
# 5            audi        sedan        99.8   177.3         ohc
# 6            audi        wagon       105.8   192.7         ohc
# 17      chevrolet    hatchback        94.5   155.9         ohc
# 19          dodge    hatchback        93.7   157.3         ohc
# 28          honda        sedan        96.5   175.4         ohc
# 34         jaguar        sedan       113.0   199.6        dohc
# 37          mazda    hatchback        93.1   159.1         ohc
# 38          mazda    hatchback        93.1   159.1         ohc
# 54         nissan        sedan        94.5   165.3         ohc
# 56         nissan        wagon        94.5   170.2         ohc
# 62        porsche  convertible        89.5   168.9        ohcf
# 69         toyota        wagon        95.7   169.7         ohc
# 81     volkswagen        sedan        97.3   171.7         ohc
#
# ...

# %%
len(df.dropna())
# Out:
# 14

# %%
df.dropna(axis=1)
# Out:
#            company   body-style num-of-cylinders
# index
# 0      alfa-romero  convertible             four
# 1      alfa-romero  convertible             four
# 2      alfa-romero    hatchback              six
# 3             audi        sedan             four
# 4             audi        sedan             five
# ...            ...          ...              ...
# 81      volkswagen        sedan             four
# 82      volkswagen        sedan             four
# 86      volkswagen        sedan             four
# 87           volvo        sedan             four
# 88           volvo        wagon             four
#
# [61 rows x 3 columns]

# %%
df.dropna(axis=1, thresh=48) # columnslardan Nan bo'lgan qiymatlarni olib tasha lekin 48 tadan kam bo'lmasin
# Out:
#            company   body-style  length engine-type num-of-cylinders    price
# index
# 0      alfa-romero  convertible   168.8        dohc             four  13495.0
# 1      alfa-romero  convertible   168.8        dohc             four  16500.0
# 2      alfa-romero    hatchback   171.2        ohcv              six  16500.0
# 3             audi        sedan   176.6         ohc             four  13950.0
# 4             audi        sedan   176.6         ohc             five  17450.0
# ...            ...          ...     ...         ...              ...      ...
# 81      volkswagen        sedan   171.7         ohc             four   7975.0
# 82      volkswagen        sedan   171.7         NaN             four   7995.0
# 86      volkswagen        sedan     NaN         ohc             four   9995.0
# 87           volvo        sedan   188.8         NaN             four  12940.0
# 88           volvo        wagon   188.8         ohc             four  13415.0
#
# [61 rows x 6 columns]

# %%
df.dropna(subset = ['price', 'horsepower']) # price va horsepower ustunidagi barcha NaN qiymatlarni tashlab yubor
# Out:
#              company   body-style  wheel-base  length engine-type  \
# index
# 1        alfa-romero  convertible         NaN   168.8        dohc
# 2        alfa-romero    hatchback        94.5   171.2        ohcv
# 3               audi        sedan        99.8   176.6         ohc
# 5               audi        sedan        99.8   177.3         ohc
# 6               audi        wagon       105.8   192.7         ohc
# 10               bmw        sedan         NaN   176.8         ohc
# 11               bmw        sedan       101.2   176.8         ohc
# 14               bmw        sedan       103.5     NaN         ohc
# 15               bmw        sedan       110.0   197.0         ohc
# 17         chevrolet    hatchback        94.5   155.9         ohc
# 18         chevrolet        sedan         NaN   158.8         ohc
# 19             dodge    hatchback        93.7   157.3         ohc
# 20             dodge    hatchback        93.7     NaN         ohc
# ...

# %% [markdown]
# # MA'LUMOTLARNI TO'LDIRISH `.fillna()` metodi

# %%
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# ...

# %%
df.fillna(0) # mavjud bo'lmagan NaN qiymatlarini o'rniga 0 quymoqchimiz. !!!Diqqat faqat arifmetik amallarni bajarguncha tavsiya qilinadi
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         0.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         0.0   171.7           0
# 86      volkswagen        sedan        97.3     0.0         ohc
# 87           volvo        sedan       104.3   188.8           0
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         0.0             21.0  13495.0
# ...

# %%
df.fillna({'horsepower':100, 'wheel-base':90})
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        90.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        90.0   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four       100.0             21.0  13495.0
# ...

# %%
np.mean(df['wheel-base']) #  wheele ustuni uchun o'rtacha qiymatni aniqladik
# Out:
# 99.2195652173913

# %%
df.fillna({'horsepower':108, 'wheel-base':99})
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        99.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        99.0   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four       108.0             21.0  13495.0
# ...

# %%
np.mean(df['horsepower']) #  horspower    ustuni uchun o'rtacha qiymatni aniqladik
# Out:
# 108.26666666666667

# %%
df.fillna({'horsepower':np.mean(df['horsepower']), 'wheel-base':np.mean(df['wheel-base'])}) # birdaniga o'rtacha qiymatini qoyib ketamiz
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible   88.600000   168.8        dohc
# 1      alfa-romero  convertible   99.219565   168.8        dohc
# 2      alfa-romero    hatchback   94.500000   171.2        ohcv
# 3             audi        sedan   99.800000   176.6         ohc
# 4             audi        sedan   99.400000   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan   97.300000   171.7         ohc
# 82      volkswagen        sedan   99.219565   171.7         NaN
# 86      volkswagen        sedan   97.300000     NaN         ohc
# 87           volvo        sedan  104.300000   188.8         NaN
# 88           volvo        wagon  104.300000   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four  108.266667             21.0  13495.0
# ...

# %%
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# ...

# %%
df.fillna(method='ffill') # NaN qiymatini ozidan oldingi qiymat bilan to'ldirish
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# ...

# %%
df.fillna(method='bfill') # NaN qiymatini ozidan keyingi qiymatni qoyadi
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        94.5   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   188.8         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four       111.0             21.0  13495.0
# ...

# %%
df[df.company=='volkswagen'].fillna(method='ffill')
# Out:
#           company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 80     volkswagen      sedan        97.3     NaN         ohc             four
# 81     volkswagen      sedan        97.3   171.7         ohc             four
# 82     volkswagen      sedan        97.3   171.7         ohc             four
# 86     volkswagen      sedan        97.3   171.7         ohc             four
#
#        horsepower  average-mileage   price
# index
# 80            NaN             37.0  7775.0
# 81           85.0             27.0  7975.0
# 82           52.0             37.0  7995.0
# 86          100.0             37.0  9995.0

# %%
df.fillna(df.mean()) #  barcha ustunlarning qiymatlarining o'rtacha qiymatlarini NaN qiymaniting o'rniga qo'yib ketadi
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#            company   body-style  wheel-base      length engine-type  \
# index
# 0      alfa-romero  convertible   88.600000  168.800000        dohc
# 1      alfa-romero  convertible   99.219565  168.800000        dohc
# 2      alfa-romero    hatchback   94.500000  171.200000        ohcv
# 3             audi        sedan   99.800000  176.600000         ohc
# 4             audi        sedan   99.400000  176.600000         ohc
# ...            ...          ...         ...         ...         ...
# 81      volkswagen        sedan   97.300000  171.700000         ohc
# 82      volkswagen        sedan   99.219565  171.700000         NaN
# ...

# %%
dfh = df[df['body-style']=='hatchback']

# %%
dfh1=dfh.fillna(dfh.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
dfh1
# Out:
#            company body-style  wheel-base   length engine-type  \
# index
# 2      alfa-romero  hatchback   94.500000  171.200        ohcv
# 16       chevrolet  hatchback   88.400000  141.100           l
# 17       chevrolet  hatchback   94.500000  155.900         ohc
# 19           dodge  hatchback   93.700000  157.300         ohc
# 20           dodge  hatchback   93.700000  159.325         ohc
# 36           mazda  hatchback   93.100000  159.100         NaN
# 37           mazda  hatchback   93.100000  159.100         ohc
# 38           mazda  hatchback   93.100000  159.100         ohc
# 39           mazda  hatchback   93.809091  159.325         NaN
# 49      mitsubishi  hatchback   93.809091  157.300         ohc
# 50      mitsubishi  hatchback   93.700000  159.325         NaN
# 63         porsche  hatchback   98.400000  175.700       dohcv
# 66          toyota  hatchback   93.809091  158.700         ohc
# 67          toyota  hatchback   95.700000  158.700         NaN
# ...

# %% [markdown]
# # Takroriy qiymatlarni o'chirish

# %%
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %%
df['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
dict = {'two':2,'three':3,'four':4,'five':5,'six':6, 'eight':8,'twelve':12}

# %%
df['cylinders'] =df['num-of-cylinders'].map(dict) # bu map metodi biror bir jadvalni boshqa bir jadvalga moslashtirish

# %%
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinders
# index
# 0                 four         NaN             21.0  13495.0          4
# ...

# %%
kurs = 10720
df['price_uzs']=df['price'].map(lambda x: x*kurs)

# %%
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinders  \
# index
# 0                 four         NaN             21.0  13495.0          4
# ...

# %%
df.replace('four',4) # replace methodi bilan four qiymatini 4 ga almashtirdik , bir qancha qiymatlarni alashtirish uchun dict qilib olish kerak
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinders  \
# index
# 0                    4         NaN             21.0  13495.0          4
# ...

# %%
df.replace(dict)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#        num-of-cylinders  horsepower  average-mileage    price  cylinders  \
# index
# 0                     4         NaN             21.0  13495.0          4
# ...

# %%
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinders  \
# index
# 0                 four         NaN             21.0  13495.0          4
# ...

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data_nan.csv", index_col='company')

# %%
df.rename(index = str.upper)
# Out:
#              index   body-style  wheel-base  length engine-type  \
# company
# ALFA-ROMERO      0  convertible        88.6   168.8        dohc
# ALFA-ROMERO      1  convertible         NaN   168.8        dohc
# ALFA-ROMERO      2    hatchback        94.5   171.2        ohcv
# AUDI             3        sedan        99.8   176.6         ohc
# AUDI             4        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# VOLKSWAGEN      81        sedan        97.3   171.7         ohc
# VOLKSWAGEN      82        sedan         NaN   171.7         NaN
# VOLKSWAGEN      86        sedan        97.3     NaN         ohc
# VOLVO           87        sedan       104.3   188.8         NaN
# VOLVO           88        wagon       104.3   188.8         ohc
#
#             num-of-cylinders  horsepower  average-mileage    price
# company
# ALFA-ROMERO             four         NaN             21.0  13495.0
# ...

# %%
df.drop(columns = 'index')
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible         NaN   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
# ...                  ...         ...     ...         ...              ...
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan         NaN   171.7         NaN             four
# volkswagen         sedan        97.3     NaN         ohc             four
# volvo              sedan       104.3   188.8         NaN             four
# volvo              wagon       104.3   188.8         ohc             four
#
#              horsepower  average-mileage    price
# company
# ...

# %%
df.rename(index = str.upper, columns = str.upper, inplace = True)

# %%
df
# Out:
#              INDEX   BODY-STYLE  WHEEL-BASE  LENGTH ENGINE-TYPE  \
# company
# ALFA-ROMERO      0  convertible        88.6   168.8        dohc
# ALFA-ROMERO      1  convertible         NaN   168.8        dohc
# ALFA-ROMERO      2    hatchback        94.5   171.2        ohcv
# AUDI             3        sedan        99.8   176.6         ohc
# AUDI             4        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# VOLKSWAGEN      81        sedan        97.3   171.7         ohc
# VOLKSWAGEN      82        sedan         NaN   171.7         NaN
# VOLKSWAGEN      86        sedan        97.3     NaN         ohc
# VOLVO           87        sedan       104.3   188.8         NaN
# VOLVO           88        wagon       104.3   188.8         ohc
#
#             NUM-OF-CYLINDERS  HORSEPOWER  AVERAGE-MILEAGE    PRICE
# company
# ALFA-ROMERO             four         NaN             21.0  13495.0
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population_duplicates.csv', index_col='country')
df1.head()
# Out:
#          rank     density   densityMi    pop2021   area
# country
# Macau       1  21946.4667  56841.3487    658.394     30
# Monaco      2  19755.5000  51166.7450     39.511      2
# Burundi    28    440.3044   1140.3884  12255.433  27834
# Macau       1  21946.4667  56841.3487    658.394     30
# Monaco      2  19755.5000  51166.7450     39.511      2

# %% [markdown]
# **Avval qator takroriy ekanini tekshirish uchun `.duplicated()` metodiga muorjaat qilamiz. Bunday takroriy qatorlar `True`, takrorlanmagan qatorlar `False` qiymatinin qaytaradi.**

# %%
df1.duplicated()
# Out:
# country
# Macau               False
# Monaco              False
# Burundi             False
# Macau                True
# Monaco               True
#                     ...
# Namibia             False
# Western Sahara      False
# Mongolia            False
# Falkland Islands    False
# Greenland           False
# Length: 247, dtype: bool

# %%
#`sum()` funksiyasi yordamida jami takrorlangan qatorlar sonini ko'rishimiz mumkin:
sum(df1.duplicated())
# Out:
# 15

# %%
df1.shape
# Out:
# (247, 5)

# %%
df1.drop_duplicates() # takrorlanadigan qatorlarni tashlab yuborish
# Out:
#                   rank     density   densityMi    pop2021     area
# country
# Macau                1  21946.4667  56841.3487    658.394       30
# Monaco               2  19755.5000  51166.7450     39.511        2
# Burundi             28    440.3044   1140.3884  12255.433    27834
# Singapore            3   8305.1915  21510.4461   5896.686      710
# Hong Kong            4   6841.3134  17719.0017   7552.810     1104
# ...                ...         ...         ...        ...      ...
# Namibia            228      3.1338      8.1166   2587.344   825615
# Western Sahara     229      2.3003      5.9577    611.875   266000
# Mongolia           230      2.1286      5.5129   3329.289  1564110
# Falkland Islands   231      0.2902      0.7517      3.533    12173
# Greenland          232      0.0263      0.0680     56.877  2166086
#
# [232 rows x 5 columns]

# %% [markdown]
# #Takroriy qiymatlarni butun jadval bo'yicha emas, ma'lum bir ustun bo'yicha ham topib o'chirish mumkin. Misol uchun, yuqoridagi jadvlada davlat nomi (`country`) yoki reytingi (`rank`) bo'yicha qidirish kifoya:

# %%
df1.drop_duplicates(['rank'])
# Out:
#                   rank     density   densityMi    pop2021     area
# country
# Macau                1  21946.4667  56841.3487    658.394       30
# Monaco               2  19755.5000  51166.7450     39.511        2
# Burundi             28    440.3044   1140.3884  12255.433    27834
# Singapore            3   8305.1915  21510.4461   5896.686      710
# Hong Kong            4   6841.3134  17719.0017   7552.810     1104
# ...                ...         ...         ...        ...      ...
# Namibia            228      3.1338      8.1166   2587.344   825615
# Western Sahara     229      2.3003      5.9577    611.875   266000
# Mongolia           230      2.1286      5.5129   3329.289  1564110
# Falkland Islands   231      0.2902      0.7517      3.533    12173
# Greenland          232      0.0263      0.0680     56.877  2166086
#
# [232 rows x 5 columns]
