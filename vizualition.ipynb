# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
 sonlar = np.arange(10)

# %%
plt.plot(sonlar)
plt.show()

# %%
x= np.arange(0,4*np.pi, 0.1)
y=np.sin(x)

# %%
plt.plot(x,y, linewidth=2.5, linestyle="-.", color="r", marker='^') # plot va show ham sonlar chizish va chizilgan narsani chop etishga hizmat qiladi
plt.show()

# %% [markdown]
# Grafiklarning turli parametrlarini o'zgartirish yordamida uning tashqi ko'rinishini ham o'zgartirish mumkin:
# - `linewidth` - chiziq qalinligi (0.5 dan 3 gacha)
# - `linestyle` - chiziq stili
#   - `-` - oddiy chiziq
#   - `--` - yuliq chiziq
#   - `-.` - chiziq va nuqta
#   - `:` - nuqtali chiziq
#   - `None` yoki `''` - chiziq yo'q
# - `color` - chiziq rangi
#   - `'b'` - ko'k (blue)
#   - `'c'` - havorang (cyan)
#   - `'g'` - yashil (green)
#   - `'k'` - qora (black)
#   - `'m'` - pushti (magenta)
#   - `'r'` - qizil (red)
#   - `'y'` - sariq (yellow)
#   - Bundan tashqari ranglar HEX (`'#FF5733'`) yoki RGBA `(255,182,193,0.5)`  formatlarida ham berilishi mumkin*.
# - `alpha` - chiziq shaffofligi (`0` shaffof, `0.5` yarim-shaffof, `1` shaffof emas)
# - `marker` - marker
#   - `'.'` - nuqta
#   - `'o'` - aylana
#   - `'v'` - pastga qaragan uchburchak
#   - `'^'` - tepaga qaragan uchburchak
#   - `'*'` - yulduz
#   - To'liq ro'yxat: https://matplotlib.org/3.1.0/gallery/lines_bars_and_markers/marker_reference.html
#
# **`*`**Turli ranglar uchun HEX va RGBA qiymatlarni https://htmlcolorcodes.com/ sahifasidan olishingiz mumkin.
# ![](https://i.imgur.com/SG3TVun.png)

# %%
plt.plot(x, y,
         linewidth=1.5,
         linestyle='-.',
         color='#8E44AD',
         alpha=0.7,
         marker='h')

# Grafik nomi:
plt.title('sin(x) funksiya grafigi')
# x - o'q nomi:
plt.xlabel("pi")
# y - o'q nomi:
plt.ylabel("sin(x)")
# Setka qo'shamiz
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(x, y,
         linewidth=1.5,
         linestyle='-.',
         color='#8E44AD',
         alpha=0.7,
         marker='h')

# Grafik nomi:
plt.title('sin(x) funksiya grafigi')
# x - o'q nomi:
plt.xlabel("pi")
# y - o'q nomi:
plt.ylabel("sin(x)")
plt.grid(color='k', alpha=0.5, linestyle='--') # setkani o'zgartirish
plt.show()

# %%
x = np.arange(0, 4 * np.pi, 0.1)
sin = np.sin(x) # sin(x)
cos = np.cos(x) # cos(x)

plt.figure(figsize=(12,6))
# sin(x) grafigi
plt.plot(x, sin,
         linewidth=1.5,
         linestyle='-.',
         color='#8E44AD',
         alpha=0.7,
         marker='h')

# cos(x) grafigi
plt.plot(x, cos,
         linewidth=1.5,
         linestyle=':',
         color='c',
         alpha=0.7,
         marker='v')

# Grafik nomi:
plt.title('sin(x) va cos(x) funksiya grafigi')
# x-o'q nomi:
plt.xlabel("pi")
# Har bir chiziq haqida ma'lumot:
plt.legend(['sin(x)','cos(x)'], loc=0, fontsize='x-large')
plt.grid(color='tomato', alpha=0.5, linestyle='--') # setkani o'zgartirish
plt.show()
